# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# **Production-Grade EDA Notebook for Credit Scoring Model**
#
# This notebook provides comprehensive exploratory data analysis following industry best practices:
# - Structured analysis workflow
# - Reproducible code
# - Clear documentation
# - Production-ready visualizations
#
# ---
#
# ## Table of Contents
# 1. [Setup and Configuration](#setup)
# 2. [Data Loading and Validation](#loading)
# 3. [Data Overview](#overview)
# 4. [Data Quality Assessment](#quality)
# 5. [Univariate Analysis](#univariate)
# 6. [Bivariate Analysis](#bivariate)
# 7. [Temporal Analysis](#temporal)
# 8. [Summary and Recommendations](#summary)

# %% [markdown]
# ## 1. Setup and Configuration {#setup}

# %%
# Standard library imports
import sys
from pathlib import Path
from typing import Dict, List, Optional
import warnings

# Third-party imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Project imports
sys.path.insert(0, str(Path.cwd().parent))
from src.utils.logging import get_logger

# Configure logging
logger = get_logger(__name__)

# Configure visualization
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (14, 6)
plt.rcParams['figure.dpi'] = 100
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['font.size'] = 10

# Configure pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# Suppress warnings
warnings.filterwarnings('ignore')

print("✓ Setup complete")
